# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials

# %%
scope = ['https://spreadsheets.google.com/feeds']
creds = ServiceAccountCredentials.from_json_keyfile_name('../sheets_backend_secret.json', scope)
client = gspread.authorize(creds)

# %%
sheet = client.open('Mitochondria BLAST hits cutoff 98%').sheet1
contents = sheet.get_all_records()

# %%
unique_values = set()
cell_list = sheet.range('A2:' + gspread.utils.rowcol_to_a1(sheet.row_count, sheet.col_count ))  # skipping header row

for cell in cell_list:
    if cell.value:
        unique_values.add(int(cell.numeric_value))

# %%
unique_values
# Out:
# {346,
#  553,
#  656,
#  932,
#  1043,
#  1200,
#  1230,
#  1266,
#  1428,
#  1622,
#  1730,
#  1744,
#  1974,
#  2042,
#  2396,
#  2539,
#  2657,
#  3131,
#  3137,
#  3303,
#  3367,
#  3572,
#  3885,
#  4181,
#  4776,
#  5073,
#  5081,
#  5122,
#  7057,
#  8046,
#  8549,
#  8716,
#  9682,
#  10213,
#  10447,
#  10846,
#  11512,
#  12971,
#  14806,
#  15729,
#  15968,
#  16241,
#  16569,
#  16668,
#  16758,
#  16857,
#  17472,
#  17934,
#  18452,
#  18958,
#  20135,
#  20316,
#  21090,
#  21558,
#  21595,
#  21605,
#  21650,
#  22457,
#  22790,
#  22791,
#  23119,
#  24471,
#  25411,
#  25650,
#  25983,
#  26431,
#  27158,
#  27918,
#  27937,
#  29098,
#  29330,
#  29420,
#  29547,
#  30030,
#  31090,
#  31791,
#  33210,
#  33670,
#  34382,
#  34408,
#  35982,
#  36376,
#  36816,
#  37019,
#  37635,
#  37734,
#  39413,
#  41461,
#  42007,
#  42043,
#  42697,
#  44468,
#  45371,
#  46560,
#  47912,
#  47988,
#  49251,
#  50239,
#  50711,
#  50937,
#  51118,
#  52370,
#  52743,
# ...

# %%
len(unique_values)
# Out:
# 463

# %%
dir(cell_list[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_col',
#  '_row',
#  'col',
#  'element',
#  'input_value',
#  'numeric_value',
#  'row',
#  'value']
